# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix

# %%
df = pd.read_csv('datasets/archive/recommendations.csv')

# %%
df.head()

# %%
from scipy.sparse import csr_matrix

# Assuming df is your DataFrame
sample_size = 50000  # Adjust the sample size as needed

# Randomly select a subset of users
random_users = df['user_id'].sample(n=sample_size, random_state=42)

# Filter the DataFrame to include only the selected users
df_subset = df[df['user_id'].isin(random_users)]

# Create a user-item matrix from the subset
user_u = list(sorted(df_subset['user_id'].unique()))
item_u = list(sorted(df_subset['app_id'].unique()))

row = df_subset['user_id'].astype('category').cat.codes
col = df_subset['app_id'].astype('category').cat.codes

data = df_subset['is_recommended'].astype(int).tolist()

user_item_matrix = csr_matrix((data, (row, col)), shape=(len(user_u), len(item_u)))
# print(random_users)

# %%
len(df_subset)

# %%
len(item_u)

# %%
user_item_matrix.shape

# %%
print(user_item_matrix[:10, :10].toarray())

# %%
from sklearn.metrics.pairwise import cosine_similarity

user_similarity = cosine_similarity(user_item_matrix, dense_output=False)

# %%
print(user_similarity.shape)
# Out:
# (49442, 49442)

# %%
def get_top_k_neighbors(user_similarity_matrix, target_user_idx, k):
    # Extract the row of cosine similarities for the target user
    target_similarities = user_similarity_matrix[target_user_idx, :]

    # Use numpy's argpartition to get the indices of the top-K (excluding the target user)
    top_k_indices = np.argsort(target_similarities.data)[-k:][::-1]
    top_k_similarities = target_similarities.data[top_k_indices]

    print(top_k_indices)
    print(top_k_similarities)

    return top_k_indices, top_k_similarities

target_user_idx = 6  # Replace with the index of your target user
k_neighbors = 100  # Adjust the number of neighbors as needed

top_k_neighbors, top_k_similarities = get_top_k_neighbors(user_similarity, target_user_idx, k_neighbors)
print("Top K Neighbors:", top_k_neighbors)
print("Top K Similarities:", top_k_similarities)
# Out:
# [3692 2622 2228 1554  178 1584 2613 1579 1568  757 1557 1551  750  765
#  3433 1523 1517  769 1500 3549  772 1480 3204 2583 3163 2581 1764  705
#  1751 2502 1744 2518 1708 1703  149 1697 1008  151  156  159  397 1654
#  1652  747 1625 3182 1437 1775 3511 2862  889  343  894  902 3080 1183
#  1164 2925 1126 2949 3463  283 1062  315 1057  977 1032 3033 1238 1249
#   817 2850 1432 2718 2736 1394 2745  222 3373 1360 2766 3145 1346 2775
#  2790 1292 1287 3130 1270 1258 2846  134 1689 3652 3417 2019 2018 3661
#   476 2011]
# [1.         0.70710678 0.57735027 0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5       ]
# Top K Neighbors: [3692 2622 2228 1554  178 1584 2613 1579 1568  757 1557 1551  750  765
#  3433 1523 1517  769 1500 3549  772 1480 3204 2583 3163 2581 1764  705
#  1751 2502 1744 2518 1708 1703  149 1697 1008  151  156  159  397 1654
#  1652  747 1625 3182 1437 1775 3511 2862  889  343  894  902 3080 1183
#  1164 2925 1126 2949 3463  283 1062  315 1057  977 1032 3033 1238 1249
#   817 2850 1432 2718 2736 1394 2745  222 3373 1360 2766 3145 1346 2775
#  2790 1292 1287 3130 1270 1258 2846  134 1689 3652 3417 2019 2018 3661
#   476 2011]
# Top K Similarities: [1.         0.70710678 0.57735027 0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.5       ]

# %%
def predict_ratings(user_item_matrix, top_k_neighbors, top_k_similarities):
    # Get the ratings of the top-K neighbors
    neighbor_ratings = user_item_matrix[top_k_neighbors, :]
    print(neighbor_ratings)
    
    # Weighted sum of neighbor ratings based on similarity
    non_weighted_sum = neighbor_ratings.sum(axis=0)
    print(type(neighbor_ratings))
    print(non_weighted_sum)
    # print(weighted_sum.shape)

    # Sum of absolute similarities for normalization
    abs_sim_sum = np.sum(np.abs(top_k_similarities))

    # Predicted ratings for the target user
    # predicted_ratings = non_weighted_sum / abs_sim_sum

    return non_weighted_sum

predicted_ratings = predict_ratings(
                        user_item_matrix, 
                        top_k_neighbors, 
                        top_k_similarities)
# Out:
#   (0, 20)	1
#   (0, 1136)	1
#   (0, 1231)	1
#   (0, 1883)	1
#   (0, 4090)	1
#   (0, 4520)	1
#   (0, 23485)	0
#   (1, 5065)	1
#   (1, 9406)	1
#   (2, 2505)	1
#   (2, 7098)	1
#   (2, 14765)	1
#   (2, 17418)	1
#   (3, 1581)	1
#   (3, 8128)	1
#   (4, 606)	1
#   (4, 1501)	0
#   (4, 5976)	1
#   (4, 7127)	1
#   (4, 8293)	0
#   (4, 13048)	1
#   (4, 18002)	1
#   (4, 19404)	0
#   (4, 19653)	0
#   (4, 20789)	1
#   :	:
#   (97, 15724)	0
#   (97, 16338)	1
#   (97, 19230)	1
#   (97, 19234)	1
#   (97, 19358)	1
#   (97, 20086)	0
#   (97, 20135)	1
#   (97, 20466)	1
#   (97, 20468)	1
#   (97, 20974)	1
#   (97, 21281)	1
#   (97, 22206)	1
#   (97, 22537)	1
#   (98, 250)	0
#   (98, 1231)	1
#   (98, 1389)	0
#   (98, 1487)	1
#   (98, 1510)	1
#   (98, 1581)	1
#   (98, 2040)	1
#   (98, 2688)	1
#   (98, 3352)	0
#   (98, 9266)	0
#   (98, 10155)	1
#   (99, 1506)	1
# <class 'scipy.sparse._csr.csr_matrix'>
# [[1 0 0 ... 0 0 0]]

# %%
predicted_ratings.max()
# Out:
# 7

# %%
# Example: Get top N recommendations
N = 10
top_recommendations = np.argsort(predicted_ratings.data)[::-1][:N]
print("Top Recommendations:", top_recommendations)
# Out:
# Top Recommendations: [[14346 19066 19065 ...  4705    16  1231]]

# %%
rec_indices = top_recommendations.tolist()

# %%
from operator import itemgetter

games = itemgetter(*rec_indices[0])(item_u)

# %%
import pickle

id_to_title = pd.read_pickle("datasets/id_to_title.pkl")

# %%
id_to_title
# Out:
# {13500: 'Prince of Persia: Warrior Within™',
#  22364: 'BRINK: Agents of Change',
#  113020: "Monaco: What's Yours Is Mine",
#  226560: 'Escape Dead Island',
#  249050: 'Dungeon of the ENDLESS™',
#  250180: 'METAL SLUG 3',
#  253980: 'Enclave',
#  271850: 'Men of War: Assault Squad 2 - Deluxe Edition upgrade',
#  282900: 'Hyperdimension Neptunia Re;Birth1',
#  19810: 'The Sum of All Fears',
#  15270: 'Cold Fear™',
#  21130: 'LEGO® Harry Potter: Years 1-4',
#  22130: 'Hearts of Iron 2 Complete',
#  29180: 'Osmos',
#  32750: 'Comanche 4',
#  241620: 'Inquisitor',
#  408520: 'FORM',
#  244910: 'Homesick',
#  245950: 'Borderlands 2: Headhunter 4: Wedding Day Massacre',
#  250460: 'Bridge Constructor',
#  278890: 'Angvik',
#  305181: 'Sniper Elite 3 - Camouflage Weapons Pack',
#  312200: 'Chasm',
#  321290: 'Dandelion - Wishes brought to you -',
#  329640: 'Eradicator',
#  367670: 'Controller Companion',
#  380810: 'Herald: An Interactive Period Drama - Book I & II',
#  392330: 'Take Command - 2nd Manassas',
#  437000: 'GUILTY GEAR 2 -OVERTURE-',
#  445420: 'Aselia the Eternal -The Spirit of Eternity Sword-',
#  458790: 'The House in Fata Morgana Original Soundtrack',
#  462280: 'Offworld Trading Company - Soundtrack DLC',
#  1872790: 'Luckitown',
#  371970: 'Barony',
#  222660: 'Retro/Grade',
#  237850: 'Dreamfall Chapters',
#  268220: 'Meltdown',
#  274270: 'NOT A HERO',
#  281450: 'Disciples Sacred Lands Gold',
#  1259750: 'Tropico 6 - Spitter',
#  296870: 'Dreaming Sarah',
#  330180: 'Pix the Cat',
#  351920: 'Crazy Machines 3',
#  397210: 'Kanji Training Game',
#  402130: 'FlatOut 4: Total Insanity',
#  402710: 'Osiris: New Dawn',
#  410970: 'Master of Orion 1',
#  415200: 'Motorsport Manager',
#  410770: 'Roads of Rome',
#  254820: 'Ground Control Anthology',
#  284180: 'Magicians & Looters',
#  286380: 'Strata',
#  288220: 'Backstage Pass',
#  302690: 'Metal Dead',
#  320388: 'Raid Mode: Album Storage C',
#  339350: 'Choice of Robots',
#  342310: 'RIOT: Civil Unrest',
#  346500: 'Road Scars: Origins',
#  393831: 'Magicka 2: Three Cardinals Robe Pack',
#  414870: 'Super Mega Baseball 2',
#  419990: 'Ganbare! Super Strikers',
#  434041: 'Mordheim: City of the Damned - The Smuggler',
#  446600: 'Magi Trials',
#  451640: 'C14 Dating',
#  479010: 'Kodon',
#  494150: 'The Thrill of the Fight - VR Boxing',
#  1198740: 'Colony Siege',
#  35000: 'Mini Ninjas',
#  37400: 'Time Gentlemen Please! and Ben There Dan That! Special Edition  Double Pack',
#  39690: 'ArcaniA',
#  65400: 'Archon Classic',
#  208805: 'Tomb Raider: Pistol Silencer',
#  222420: "THE KING OF FIGHTERS '98 ULTIMATE MATCH FINAL EDITION",
#  274480: 'Drox Operative',
#  314000: 'Pool Nation FX Lite',
#  326410: 'Windward',
#  355920: 'Pixel Puzzles 2: Space',
#  406600: 'METAL GEAR SOLID V: THE PHANTOM PAIN - Jumpsuit (EVA)',
#  940980: "Phantasmat: The Dread of Oakville Collector's Edition",
#  433550: 'DARQ: Complete Edition',
#  436550: 'Homeworld: Deserts of Kharak - Soundtrack',
#  438450: '3DF Zephyr Lite Steam Edition',
#  439500: "LEGO® MARVEL's Avengers DLC - The Masters of Evil Pack",
#  910320: 'Three Kingdoms 2019 阿达三国志2019 横版',
#  284750: 'Enigmatis: The Ghosts of Maple Creek',
#  298930: 'Darkness Within 1: In Pursuit of Loath Nolder',
#  302350: 'Tex Murphy: Under a Killing Moon',
#  308270: "Buzz Aldrin's Space Program Manager",
#  317030: "Fatty Bear's Birthday Surprise",
#  325990: 'Train Simulator: Semmeringbahn - Mürzzuschlag to Gloggnitz Route Add-On',
#  376980: 'Invisible Inc. Contingency Plan',
#  382400: 'Dungeons 2 - A Game of Winter',
#  388290: 'Just Cause™ 3 - Combat Buggy',
#  402260: 'Dead Secret',
#  429300: 'Sepia Tears',
#  435300: 'We Know the Devil',
#  450500: 'Ace of Seafood',
#  466546: 'The Phantom Limb Level Pack',
#  558240: 'Euro Truck Simulator 2 - Dragon Truck Design Pack',
#  563190: 'de Blob 2',
#  574310: 'The Mooseman',
#  929103: 'ACE COMBAT™ 7: SKIES UNKNOWN - F-4E Phantom II + 3 Skins',
#  939060: 'Farm Together - Supporters Pack',
#  520720: 'Dear Esther: Landmark Edition',
#  527420: 'Demon Hunter 3: Revelation',
#  529590: "Please Don't Touch Anything 3D",
#  545600: 'Vigilantes',
#  555530: 'A-10C: Advanced Aircraft Training Qualification Campaign',
#  555580: 'The Legend of Dark Witch 2 （魔神少女エピソード２）',
#  610070: 'Rain World - Soundtrack',
#  657280: 'Rytmik Studio',
#  727980: 'Injustice™ 2 - Black Manta',
#  739210: 'My Coloring Book: Transport',
#  765410: 'Bean Battles',
#  765770: "Forest Legends: The Call of Love Collector's Edition",
#  769750: 'Gravel Ice and Fire',
#  829960: 'MechWarrior Online™ Solaris 7 Hero Pack',
#  864610: 'Magic Realm: Online',
#  884420: 'The Last Wizard',
#  412790: "Adventure Time: Magic Man's Head Games",
#  367120: 'Seduce Me the Otome',
#  395620: 'Ittle Dew 2+',
#  401628: 'Batman™: Arkham Knight - GCPD Lockdown',
#  457570: 'Camp Sunshine',
#  467760: "Trapper's Delight",
#  480520: 'Street Fighter V - Capcom Pro Tour 2016 Pack',
#  522120: 'RWBY: Grimm Eclipse - JNPR',
#  358141: 'Halloween + Debut Costume Set',
#  542770: 'Castle Must Be Mine',
#  581270: "Old Man's Journey",
#  583270: 'Cosmic Express',
#  589530: 'Hakuoki: Kyoto Winds',
#  620220: 'Catmaze',
#  622680: 'Mayhem in Single Valley',
#  640900: "King Arthur's Gold: Flags of the World Heads Pack",
#  654220: 'Flash Point: Fire Rescue',
#  684450: 'Surviving the Aftermath',
#  686710: 'Shantae: Friends to the End',
#  696370: 'BROKE PROTOCOL: Online City RPG',
#  416420: "NARUTO SHIPPUDEN: Ultimate Ninja STORM 4 - Shikamaru's Tale Extra Scenario Pack",
#  460120: 'Megadimension Neptunia VII',
#  460430: 'The Letter - Horror Visual Novel',
#  491492: 'FSX Steam Edition: McDonnell Douglas A-4 Skyhawk™ Add-On',
#  498310: 'RPG in a Box',
#  537770: "Gal*Gun: Double Peace - 'Pheromone Z' Item",
#  550400: "Delicious - Emily's Hopes and Fears",
#  568040: 'Macbat 64',
#  584096: 'Little Nightmares The Hideaway DLC',
#  588730: 'Majotori',
#  292050: "Valkyrie Hat (or 'Buy Us Coffee') DLC for Secrets of Grindea",
#  623280: 'Dungeons & Dragons: Dark Alliance',
#  673130: 'AMID EVIL',
#  699180: 'Human-powered spacecraft',
#  711681: 'Dungeons 3 - Lord of the Kings',
#  732400: 'PlataGO! Super Platform Game Maker',
#  755790: 'Ring of Elysium',
#  758580: "Grim Tales: The Wishes Collector's Edition",
#  758980: "Poker Legends: Texas Hold'em Poker Tournaments",
#  316447: 'DW8XLCE - UNIQUE WEAPON PACK',
#  319017: 'Hyperdimension Neptunia Re;Birth1 Additional Content1',
#  528050: 'Tales of Berseria™ - Summer Holiday Costume Pack',
#  566530: 'Mass Exodus Redux',
#  567340: 'The Deal',
#  570770: '古剑奇谭二(GuJian2)',
#  573320: 'Underhero',
#  580640: 'End State',
#  599610: 'Lost Words: Beyond the Page',
#  603330: 'Blasted Road Terror',
#  605990: "Heart's Medicine - Hospital Heat",
#  358370: 'Terminal Velocity',
#  665270: '弹幕音乐绘 ～风雷幻奏曲～ / Barrage Musical  ~A Fantasy of Tempest~',
#  672630: 'Academia : School Simulator',
#  716710: '東方憑依華\u3000～ Antinomy of Common Flowers.',
#  727910: 'Titanic: The Experience',
#  728300: 'F-15C: The Georgian War Campaign',
#  734740: '100% Orange Juice - Core Voice Pack 1',
#  746820: 'Tempest - Jade Sea',
#  779280: 'The Disappearing of Gensokyo: Sakuya Koishi Suika Character Pack',
#  815450: 'Cardinal Cross',
#  448240: 'Hybrid Animals',
#  453400: 'Squad - Original Soundtrack Vol. 1 & 2',
#  453990: "Mibibli's Quest",
#  463720: 'Goat Simulator: Waste of Space',
#  465720: 'Demon Hunter 2: New Chapter',
#  470210: 'Rocketbirds 2 Evolution',
#  493080: 'Card Quest',
#  497780: 'Recursed',
#  525480: '.hack//G.U. Last Recode',
#  530595: 'Defense Coin & Madhouse Mode Unlock',
#  544390: 'NITE Team 4 - Military Hacking Division',
#  554820: 'VideoPad Video Editor',
#  359496: 'Lady & Trish Costumes',
#  6880: 'Just Cause',
#  566540: 'Labyrinth of Refrain: Coven of Dusk',
#  582500: 'We Were Here',
#  708760: 'Social Club VR : Casino Nights',
#  720750: "LEGO® Marvel Super Heroes 2 - Marvel's Black Panther Movie Character and Level Pack",
#  756440: 'Your Bunny Wrote',
#  758480: 'Ukrainian ball in search of gas',
#  826540: 'Audio Trip',
#  575940: 'The Tenth Line',
#  589860: 'SoulSet',
#  604240: 'Shotgun Farmers: Grow Your Guns',
#  605920: 'VOLTED',
#  613230: 'Planescape: Torment: Enhanced Edition Official Soundtrack',
#  617160: 'Home Sweet Home',
#  645500: 'Cat Sorter VR',
#  684050: 'Achievement Idler: Black',
#  704300: 'Bartender VR Simulator',
#  736580: 'CPUCores :: Network Monitor Lite',
#  744680: 'Neverwinter Nights: Heroes of Neverwinter',
#  749840: 'The Boogie Man',
#  786990: 'SpellKeeper',
#  801980: 'Kingdom Come: Deliverance – Artbook',
#  2277010: 'Postmouse Soundtrack',
#  803600: 'Disgaea 5 Complete',
#  824720: 'Pure Rock Crawling',
#  834760: 'Robot Wants It All',
#  850450: 'Escape First',
#  1600150: 'Tiny Bunny: Full Soundtrack',
#  1568680: 'DJMAX RESPECT V - Portable 3 PACK',
#  55100: 'Homefront',
#  208292: 'Train Simulator: Southern Pacific Cab Forward Loco Add-On',
#  221910: 'The Stanley Parable',
#  222573: 'Train Simulator: Western Pacific GP20 High Nose Loco Add-On',
#  260690: 'Dark Fall: The Journal',
#  267780: 'Talisman - The Highland Expansion',
#  287900: 'Pro Pinball Ultra',
#  292800: 'Pajama Sam 3: You Are What You Eat From Your Head To Your Feet',
#  296470: 'Mount Your Friends',
#  343370: 'SLAMMED!',
#  350640: "Sherlock Holmes: The Devil's Daughter",
#  353850: 'Reassembly Soundtrack',
#  358190: 'Blake Stone: Aliens of Gold',
#  358220: 'Mystic Towers',
#  929480: 'Hatsune Miku VR - 5 songs pack 1',
#  319810: 'RER2 Episode Two: Contemplation',
#  360650: '12 Labours of Hercules III: Girl Power',
#  365380: 'Battle Brothers - Soundtrack',
#  215100: 'Ragnarok Online',
#  6040: 'The Dig®',
#  3920: "Sid Meier's Pirates!",
#  15920: 'Luxor 2',
#  25010: 'Lugaru HD',
#  31900: 'Nancy Drew®: The Creature of Kapu Cave',
#  31220: 'Sam & Max: The Devil’s Playhouse',
#  206690: 'iBomber Defense Pacific',
#  213350: 'MDK2 HD',
#  65270: 'Demolition Company Gold Edition',
#  224960: 'Tomb Raider I',
#  65600: 'Gothic 3: Forsaken Gods Enhanced Edition',
#  33180: 'Zombie Shooter 2',
#  246300: 'Paranormal',
#  914890: 'Nine Noir Lives',
#  920567: 'Resident Evil 2 - Original Ver. Soundtrack Swap',
#  971690: 'Cake Bash',
#  984470: 'Big Dipper',
#  998790: 'Piczle Lines DX+α',
#  1016770: 'Interrogation: You will be deceived',
#  1046230: 'Soccer Player Simulator',
#  1054340: 'Logic World',
#  1072480: 'The Fisherman - Fishing Planet',
#  1087760: 'The Gunk',
#  1096410: 'Vampire: The Masquerade - Coteries of New York',
#  1101930: 'Monsters of Little Haven',
#  1109050: 'Tales of Arise - Pre-Order Bonus Pack',
#  1796170: 'Bunny e-Shop  The Art of the Game',
#  793450: 'Desecration of Wings',
#  815150: 'Knight Bewitched',
#  843430: 'Righty Tighty XL',
#  846800: 'Diner Bros',
#  961490: 'Travis Strikes Again: No More Heroes Complete Edition',
#  382210: 'Blood Bowl 2 - Lizardmen',
#  848500: 'Sniper Strike: Special Ops',
#  853480: 'Pestis',
#  891170: 'The Witch & The 66 Mushrooms',
#  917150: 'Godhood',
#  917190: 'TerraTech - Official Soundtrack',
#  929100: 'ACE COMBAT™ 7: SKIES UNKNOWN - Unexpected Visitor',
#  931000: "URUZ 'Return of The Er Kishi'",
#  976920: 'Dance of Death: Du Lac & Fey',
#  987270: "Hyperdimension Neptunia Re;Birth3 Let's Get Nepucated",
#  992050: 'Oik 5',
#  1011900: 'Mirror: Enchanting Reflections',
#  1086481: 'Hearts of Iron IV: Radio Pack',
#  1536700: 'Hidden Through Time - Road to Rome',
#  215004: 'Victoria II: Interwar Engineer Unit',
#  919640: 'Steel Division 2',
#  774791: 'Surgeon Simulator 2',
#  783120: 'HELLO LADY!',
#  818960: 'TAYAL',
#  820540: 'Bloodroots',
#  837861: 'Alien Shooter - The Experiment',
#  896640: 'Dead In Vinland - The Vallhund',
#  933610: 'Euro Truck Simulator 2 - Krone Trailer Pack',
#  933940: '假如我是人工智能 Big Brother Is Shaping You',
#  946780: 'MOMO.EXE 2',
#  958320: 'A Front Too Far: Normandy',
#  959410: 'The Endless Empty',
#  962630: 'Transient: Extended Edition',
#  971070: "Dark Parables: The Match Girl's Lost Paradise Collector's Edition",
#  976900: 'Lumberhill',
#  1015480: 'DrumBeats VR',
#  1032430: 'Blood Trail',
#  1036760: 'Northgard - Svardilfari Clan of the Horse',
#  1038280: 'Nobodies: Murder Cleaner',
#  939790: 'Royal Alchemist',
#  856210: 'bit Dungeon III',
#  868420: 'Just Cause™ 4: Deathstalker Scorpion Pack',
#  885440: 'Easy Audio Visualization',
#  888850: 'NTBSS: Master Character Training Pack - Jiraiya',
#  895600: 'Mojo',
#  938220: 'TAPSONIC BOLD',
#  938490: 'Syrian Warfare: Battlefields',
#  964230: 'FUTURE GPX CYBER FORMULA SIN VIER',
#  994910: 'Poker Master',
#  996450: "7th Sea: A Pirate's Pact",
#  1054700: 'Back To Ashes',
#  1054990: 'Race With Ryan',
#  1761570: 'Hunt: Showdown - Cold Blooded',
#  1081870: 'WarForwards',
#  1124080: "Active DBG: Brave's Rage",
#  1151930: 'Buissons',
#  958210: 'Pixelmash',
#  829280: 'Kaze and the Wild Masks',
#  847290: 'Community College Hero: Knowledge is Power',
#  848930: 'Rising Dusk',
#  853380: 'Air Threat',
#  861090: 'ONE PIECE World Seeker Extra Episode 1: Void Mirror Prototype',
#  861880: 'Train Simulator: CPRR 4-6-0 Buffalo Steam Loco Add-On',
#  905450: 'NASCAR Heat 3',
#  916060: 'Loca-Love My Cute Roommate',
#  949290: 'Winkeltje: The Little Shop',
#  992172: 'DRAGON BALL FighterZ - Goku (GT)',
#  1012560: 'Snakeybus',
#  1013910: "Aron's Adventure",
#  1045010: 'Russia Roguelike',
#  1048580: "Terje Haakonsen's Powder VR",
#  1053250: 'TOK HARDCORE',
#  1066430: 'Kwaidan ～Azuma manor story～',
#  1071130: 'The Procession to Calvary',
#  1087451: 'NTBSS: Master Character Training Pack - Neji Hyuga',
#  1092630: 'Rogue Glitch',
#  1099170: 'Battle Planet - Judgement Day',
#  1112340: 'The Dreadful Whispers',
#  1112790: 'Automation Empire',
#  1189680: 'Degraman: Act I. Vincent',
#  1203510: 'Pinball FX3 - Williams™ Pinball: Volume 5',
#  1232520: 'Wish Original Soundtrack',
#  1233260: 'FAIRY TAIL',
#  1241275: 'Monster Hunter World: Iceborne - Pendant: White Felyne Teddy',
#  1250250: 'NAMCO MUSEUM ARCHIVES Vol 1',
#  1273690: 'Ashwalkers',
#  1285020: 'Flipon',
#  1287530: 'Lords and Villeins',
#  1310990: 'Bishojo Mangekyo Kotowari to Meikyu no Shojo',
#  1325800: 'Viticulture Essential Edition',
#  1326000: 'Sakura Succubus 2',
#  1415140: 'Kandidatos Kart',
#  1418844: 'Train Sim World® 2: Cane Creek: Thompson - Potash Route Add-On',
#  1235763: 'The Sims™ 4 Kids Room Stuff',
#  1482860: 'Idle Research',
#  1490340: 'We Are OFK',
#  1492070: 'Sker Ritual',
#  1501150: 'Pebble Witch',
#  1523720: 'Cook-Out',
#  1562700: 'SANABI',
#  1640760: 'WORDLAND 2',
#  1677180: 'Neko Hacker Plus',
#  1700220: '东方远空界 ~ Ultimate Vitality of Imagination',
#  1742840: 'Puff Town',
#  1797280: 'Chernobylite - Autumn Dread Pack',
#  1885690: 'Virtual Circuit Board',
#  1906530: 'A Plague Tale: Requiem - Protector Pack DLC',
#  1962430: 'Monochrome Mobius: Rights and Wrongs Forgotten',
#  2147630: 'Monster Roadtrip Playable character - Hazel',
#  1910790: 'Lunar Mirror',
#  1911560: 'Class Escape',
#  1940752: "Monster Hunter Rise - 'Relunea Bottoms' Hunter layered armor piece",
#  1115580: 'Grand Brix Shooter',
#  1128880: 'The Backrooms Game - Support This Game! 😎👉👉',
#  1149710: 'Tesla Force',
#  1179450: 'RISK: Global Domination - Premium Mode',
#  1185600: 'The Kingdom of God',
#  1202310: 'Sakura Succubus',
#  1203040: 'ONE PIECE: PIRATE WARRIORS 4 The Worst Generation Pack',
#  1286280: 'Pronty',
#  1298050: 'Boinihi: The Ki Codex',
#  1305310: 'Drox Operative 2',
#  1333410: 'Stream Racer',
#  1343920: 'Mighty Fling',
#  1364034: 'Train Simulator: Canadian Pacific AC4400CW Loco Add-On',
#  1365020: 'RIDE 4 - Credits Multiplier',
#  1370050: 'Trek to Yomi',
#  1423090: 'Monster Collector',
#  1464980: "UNREAL LIFE Original Soundtrack 'Sound of the Mind'",
#  1482081: 'Persona® 5 Strikers - All-Out Attack Pack',
#  1198960: 'PC Building Simulator - NZXT Workshop',
#  73095: 'Magicka: Mega Villain Robes',
#  1061610: 'Tenderfoot Tactics',
#  1064460: 'Murder House',
#  1066290: '猎魔者战纪',
#  324250: 'Knights of Pen and Paper - Haunted Fall',
#  1076160: 'Command: Modern Operations',
#  1081510: 'She Sees Red - Interactive Movie',
#  1090183: 'NTBSS Master Character Training Pack - Kawaki',
#  1115050: 'Will You Snail?',
#  1122700: 'Hindsight',
#  1126310: '风信楼',
#  1139110: 'Rise of Industry: 2130',
#  1141360: 'Dungeon Dreams (Female Protagonist)',
#  1180491: 'Hunt: Showdown - The Researcher',
#  1191580: 'Nexomon',
#  1201270: 'A Space for the Unbound',
#  1266430: 'Lost In Fantaland',
#  918110: 'Animus - Stand Alone',
#  818610: 'The Great Gaias',
#  870690: 'Galaxy Trucker: Extended Edition',
#  887900: 'egg is broken. heart is too.',
#  904370: 'Naval Action - Flags',
#  947300: 'Grim Nights',
#  975280: 'Will To Live Online - Supporters pack',
#  943380: 'Timberman VS',
#  979400: 'Last Labyrinth（ラストラビリンス）',
#  987480: '花落冬陽 Snowdreams -lost in winter-',
#  1007520: "Willy Jetman: Astromonkey's Revenge",
#  1027120: 'Bravery Network Online',
#  1062830: 'Embr',
#  1093330: 'Conscious Existence - A Journey Within',
#  1093800: "Zeke's Peak",
#  1102380: 'Order of Battle: Red Star',
#  368180: 'Polyball',
#  384360: 'Fingered',
#  399780: 'Expand',
#  400940: 'Budget Cuts',
#  403410: 'ARCADE GAME SERIES: Ms. PAC-MAN',
#  421040: 'Plantera',
#  428690: 'Youtubers Life',
#  439750: 'The Lost Heir 2: Forging a Kingdom',
#  1291790: 'Lakeview Cabin 2',
#  440650: 'Niche - a genetics survival game',
#  456180: 'The American Dream',
#  461950: 'Beat Cop',
#  462680: 'BalanCity',
#  485490: 'Dungeon Journey',
#  492530: 'The Dark Legions',
#  499520: 'The Turing Test',
#  539670: 'Sakura Nova',
#  1102130: 'Florence',
#  1152320: 'Atelier Shallie: Alchemists of the Dusk Sea DX',
#  1152420: 'Heraldry Studio',
#  1174720: 'SwarmZ',
#  1175460: 'Revita',
#  1181840: 'HIVESWAP: ACT 2',
#  1215110: 'Azur Lane Crosswave - Deluxe Pack',
#  1222400: 'The Soul Stone War',
#  1272930: 'Remnants Supporter Pack',
#  1287030: "Bubble Bobble 4 Friends: The Baron's Workshop",
#  924150: 'Farm Together - Ginger Pack',
#  1296980: 'Forgotten Fields',
#  1384940: 'Egression',
#  1472192: 'DJMAX RESPECT V - Tok! Tok! Tok! Gear Pack',
#  1477920: 'Night Book',
#  1481490: 'Hood: Outlaws & Legends - Forest Lords Pack',
#  1503530: 'Minit Fun Racer',
#  1512390: 'The Whispering Valley | La vallée qui murmure',
#  578320: "Dark Parables: Jack and the Sky Kingdom Collector's Edition",
#  596000: 'The Shattering',
#  618970: 'Outcast - Second Contact',
#  676630: 'Attentat 1942',
#  687540: 'Tasty Planet',
#  701870: 'Swarm Queen',
#  723790: 'The Pirate: Plague of the Dead',
#  760650: 'Hammerting',
#  761821: 'Far Cry® 5 - Hours of Darkness',
#  837860: 'Alien Shooter - Fight for Life',
#  873880: 'Railway Empire - The Great Lakes',
#  881680: 'Mouse Enhancer Pro',
#  888701: 'Varenje - Full Game DLC',
#  894270: 'Beware of Trains',
#  552520: 'Far Cry® 5',
#  981020: 'Clea',
#  1238520: 'Dandelions in the Sky',
#  1483100: 'One More Dungeon 2',
#  1491780: 'Bloody Paws Unleashed',
#  1524400: 'Ragdoll: Fall Simulator',
#  1532460: 'The Fridge is Red',
#  1543380: 'I Fetch Rocks',
#  1564090: 'Landlord of the Woods',
#  1567200: 'The Wolf',
#  1572040: 'Through The Fragmentation',
#  1594400: 'GAI Stops Auto: Right Version Simulator',
#  1617270: 'The Faraway Land',
#  1662480: 'Nuclear Blaze',
#  1739300: 'Smack Studio',
#  1743380: 'SCP: Doki Doki Anomaly',
#  1763920: 'Impostor Factory Soundtrack',
#  1764820: 'PYRMD',
#  237050: 'Sanctum 2: Ruins of Brightholme',
#  1171370: 'The Supper',
#  1174580: 'Dying Light - Harran Inmate Bundle',
#  1202870: 'The Heiress of Sorcery',
#  1203041: 'ONE PIECE: PIRATE WARRIORS 4 Land of Wano Pack',
#  1216710: 'Cyber Manhunt',
#  1218920: 'Sunset Kingdom',
#  1222690: 'Dragon Age™ Inquisition',
#  1224940: 'Tropico 6 - Original Soundtrack',
#  1238100: "Titanfall® 2: Monarch's Reign Bundle",
#  1276040: 'Mini Words: Top Movies',
#  1278500: 'Tower! 3D',
#  1293900: 'NOMAD',
#  1300211: 'DJMAX RESPECT V - BLACK SQUARE PACK',
#  1321580: 'The Horus Heresy: Legions - Starter Bundle',
#  1338630: 'Craft The World - Heroes',
#  1413660: 'Elderand',
#  1448800: 'BioCrisis',
#  1489110: 'Zapling Bygone',
#  1532920: 'Clutter IX: Clutter IXtreme',
#  1208260: 'Hentai Vs Furries',
#  1273220: 'Sphere - Flying Cities',
#  1168680: 'Cooking Simulator - Cooking with Food Network',
#  1278170: 'Big Rumble Boxing: Creed Champions',
#  1330470: 'F.I.S.T.: Forged In Shadow Torch',
#  1348390: 'I am an Air Traffic Controller 4',
#  1415420: 'Lost Castle: The Old Ones Awaken / 失落城堡: 遗迹守护者',
#  1425730: 'Gal*Gun Returns',
#  1442160: 'ABYSS OF THE SACRIFICE',
#  1458920: 'Meridian 157: Chapter 1',
#  1471530: '100 hidden gnomes',
#  1475420: 'Puzzling Peaks EXE',
#  1503670: "[Chilla's Art] The Caregiver | 終焉介護",
#  1519490: 'The Doors of Trithius',
#  1578357: 'F1® 2021: Braking Point Content Pack',
#  1627150: 'Retro Classix: Joe & Mac Returns',
#  1630580: 'Legend of Keepers: Return of the Goddess',
#  1131140: 'The MoneyMakers Rallye',
#  1140660: 'Fernbus Simulator - Belgium',
#  1155760: '嗜血印 Bloody Spell DLC 女祭司',
#  1159030: 'Euro Truck Simulator 2 - Bulgarian Paint Jobs  Pack',
#  1163550: 'Captain Tsubasa: Rise of New Champions',
#  1181770: "Beat Saber - Tokyo Machine – 'PLAY'",
#  1098340: 'Zup! 9',
#  1210340: 'Breakneck City',
#  1232252: 'Borderlands 3: Gold Weapon Skins Pack',
#  1258480: 'Aladdin - Hidden Objects Game',
#  1263820: 'sok-worlds',
#  1336560: 'Hashiriya Drifter-Online Drift Racing Multiplayer (DRIFT/DRAG/RACING)',
#  1342070: 'The Triumphant Return of Diabolos',
#  1355650: 'Filcher',
#  1365390: 'Facility 47',
#  1414000: 'Obscurite Magie: The City of Sin',
#  1425130: 'Forgotten Hill First Steps',
#  1457510: 'The Legend of Heroes: Sen no Kiseki IV -THE END OF SAGA-',
#  1475430: '天师',
#  1324000: 'Holdfast: Nations At War - Regiments of the Line',
#  1778500: "Dee's Nuts",
#  1797973: 'MONSTER HUNTER RISE - Hunter Voice: Hinoa the Quest Maiden',
#  1866430: 'Rhapsody: A Musical Adventure',
#  1902820: 'Virtual AI - Lily',
#  1926170: 'Forgotten Hill Tales',
#  1943370: 'Invercity',
#  44620: 'STCC The Game 2 – Expansion Pack for RACE 07',
#  320351: 'RER2 Episode Four: Metamorphosis',
#  2009860: 'Tower Escape',
#  1952760: 'RGB Rush',
#  1982490: "Touhou Mystia's Izakaya - Soundtrack 3",
#  2139271: 'Call of Duty League™ - Seattle Surge Pack 2023',
#  2198872: 'theHunter Call of the Wild™ - New England Veteran Cosmetic Pack',
#  2232290: 'From The Rain',
#  1624830: 'Path of Sacrifice',
#  1705150: 'SKULL CHAINZ',
#  1713870: 'ATOM RPG Trudograd - Supporter Pack',
#  1733060: 'Ever Seen A Cat?',
#  1824010: 'QuaQua',
#  1851020: 'River City Girls Zero',
#  1073320: "Meteorfall: Krumit's Tale",
#  1643260: 'Rogue Company - Year 1 Pass',
#  1689810: 'Super Robot Wars 30 - Bonus Mission Pack',
#  1707400: 'Larcin Lazer',
#  1740660: 'Miraculous: Rise of the Sphinx',
#  1855500: 'Neko Doll',
#  1968340: 'Project Gunship',
#  1198060: "Christmas Stories: Enchanted Express Collector's Edition",
#  1969060: 'Path of the Midnight Sun',
#  1969100: "MIGHT'N MOW'EM",
#  2007050: 'Penguins Can Fly',
#  2053360: 'PUTRID SHOT ULTRA',
#  2074940: "Phantom Alchemy ~Silvia's Dynamic Urban Planning~",
#  2091250: 'Koishi Navigation Desktop Youkai',
#  2105000: 'Super Choppy Orc',
#  1250520: 'Love Spell: Written In The Stars - a magical romantic-comedy otome',
#  1135432: 'Wreckfest - Modified Monsters Car Pack',
#  203766: 'Binary Domain - Multiplayer Map Pack',
#  1485070: 'Esse Proxy',
#  1514860: 'SuchArt - Supporter Pack',
#  1520710: 'Entodrive',
#  1532800: 'Squirrel Divorce',
#  1573750: '100 hidden mushrooms',
#  1586840: 'ppL',
#  809140: 'Cliff Empire',
#  1604780: 'Lovely Planet Remix',
#  1614270: 'Submerged: Hidden Depths',
#  1617870: 'Chef: Eastern Asian Cuisine',
#  1652710: 'MouseBot: Escape from CatLab',
#  1658870: 'New Home: Medieval Village',
#  1737350: 'World of Tanks — Rugged Mountaineer Pack',
#  1745280: 'Magitek VR',
#  1791690: 'Legend of Keepers: Feed the Troll',
#  1817560: 'VOIDCRISIS',
#  1832950: 'One More Gate : A Wakfu Legend',
#  1523510: 'Cave Digger 2: Dig Harder',
#  1537870: "Life is Strange Remastered Collection 'Zombie Crypt' Outfit",
#  1547380: 'KINGDOM of the DEAD',
#  1594460: 'I See Red',
#  1641830: 'Axis Football 2021',
#  1642040: 'BzzzController',
#  1663640: 'The Last Oricru',
#  1714320: 'Find Love or Die Trying',
#  1726520: 'Cyber Hook - Lost Numbers DLC',
#  1436950: "Sid Meier's Civilization® VI: Vietnam & Kublai Khan Pack",
#  1761900: 'EXOME',
#  1840660: 'Mad Adventures',
#  1965800: 'Dice Tribes: Ambitions',
#  1969820: 'Legacy of Sin blood oath',
#  2019730: '3DMark Speed Way Upgrade',
#  2085360: 'Insomnia: Theater in the Head',
#  2089350: 'Hatsune Miku Logic Paint S',
#  2091500: 'Warlords Under Siege',
#  1536080: 'Sword and Fairy 3 Ex',
#  1574910: 'The Bart Bonte collection',
#  1620720: 'The Forest Quartet',
#  1665500: 'Hypnagogia 無限の夢 Boundless Dreams',
#  1683690: 'Skiing VR',
#  1685510: 'Couch Combat',
#  1690440: 'Another Tomorrow',
#  1694600: 'THE HOUSE OF THE DEAD: Remake',
#  1215050: 'Car Mechanic Simulator 2018 - Mercedes-Benz DLC',
#  1709180: 'Solitaire Expeditions',
#  1723560: 'Ballads of Hongye',
#  1734470: 'ROUGH KUTS: The Thirsty Dead',
#  1781960: 'Sigil of the Magi',
#  1798067: "MONSTER HUNTER RISE - 'Li'l Wingdrake' Cohoot outfit",
#  1858560: 'Touhou Monster TD ~ Nagae Iku DLC',
#  1861290: 'Devil Spire',
#  1137540: 'Ultimate Fishing Simulator - VR DLC',
#  22430: 'Fallout 3 - Mothership Zeta',
#  38410: 'Fallout 2: A Post Nuclear Role Playing Game',
#  38450: 'MDK',
#  41070: 'Serious Sam 3: BFE',
#  99612: 'Civilization V - Civ and Scenario Pack: Korea',
#  112100: 'Avadon: The Black Fortress',
#  200080: "Nancy Drew®: Shadow at the Water's Edge",
#  227200: 'Waking Mars',
#  269310: 'Infectonator: Survivors',
#  287070: 'Battle Academy',
#  297860: 'Split/Second',
#  301760: 'Disney•Pixar Cars 2: The Video Game',
#  329650: 'NAM',
#  335420: 'ルナティックドーン 前途への道標',
#  351100: 'Niffelheim',
#  1636840: 'Predator: Hunting Grounds - Isabelle DLC Pack',
#  986280: 'Lingua Fleur: Lily',
#  992910: 'The Black Masses',
#  1010750: 'Blood™ Fresh Supply',
#  1016250: '100$',
#  1019310: 'VirtuaVerse',
#  1028894: 'Warhammer 40000: Inquisitor - Martyr - Desperate Crusade',
#  1029630: 'Power & Revolution 2019 Edition',
#  1047440: 'DATE A LIVE: Rio Reincarnation',
#  1097710: 'The Grim and I',
#  1112830: 'The Watchers',
#  1125910: 'Crowns and Pawns: Kingdom of Deceit',
#  1133120: 'Ecosystem',
#  465070: 'TRIZEAL Remix',
#  1144400: 'Senren＊Banka',
#  1182920: 'Movavi Video Editor Plus 2020 - Video Editing Software',
#  1191210: 'Seek Girl Ⅲ',
#  205636: 'Tropico 4: Apocalypse',
#  2093320: 'Coloring Pixels - Bakery Pack',
#  2105980: '会计模拟器',
#  2109610: 'Police Radar',
#  2158500: 'Monster Girl2',
#  2203060: '蜀山：初章 - 豪华版升级包',
#  2233890: 'Prison Wars',
#  1267540: 'WRC 9 FIA World Rally Championship',
#  1272450: 'Mahjong Deluxe',
#  1294060: '铁道少女:梦想轨迹 2.0 Railway To Dream',
#  1327430: 'Pinku Kult Hex Mortis',
#  1371400: "Monster Hunter: World - The Handler's Cute Demoness Costume",
#  1385650: 'Hot Pot For One',
#  1386620: 'Anuchard',
#  1388860: 'Unmemory',
#  1418230: 'Steel Division 2 - Nemesis #2 - Lvov Offensive',
#  557240: 'Afterlife',
#  1496640: 'Scrapping Simulator',
#  1549180: 'Propnight',
#  1562870: 'Mind Rite',
#  211160: 'Viking: Battle for Asgard',
#  1851340: 'Neon Abyss - Chrono Trap',
#  1859360: 'Dungeon Village',
#  2000110: 'Glory of war',
#  2077590: 'Sidestep Legends',
#  2119490: 'TRAHA Global',
#  2131350: 'My Coworker is an Idiot',
#  2210140: "Assassin's Creed® Valhalla - Dawn of Ragnarök",
#  871570: 'Summer Memory of Bell',
#  882790: 'Fate Seeker',
#  909610: 'SYNTHETIK - Supporter Pack',
#  918670: 'Jewel Match Twilight Solitaire',
#  959860: 'The Valiant',
#  995770: '100% Orange Juice - Toy Store Pack',
#  1006220: 'Type Knight',
#  1015720: 'Alternate DiMansion Diary',
#  1034720: 'GreedFall - Adventurer’s Gear DLC',
#  512260: 'Avalon Legends Solitaire 2',
#  1034750: 'The Flower Collectors',
#  1051380: 'Farm Together - Oxygen Pack',
#  1065970: '狼と香辛料VR/Spice&WolfVR',
#  1067220: 'RoboCo',
#  346470: 'Tennis Elbow 2013',
#  447310: 'Paper Train Traffic',
#  449393: "LEGO® MARVEL's Avengers DLC - Marvel’s Ant-Man Pack",
#  485120: 'Frog Climbers',
#  490930: 'Need to Know',
#  518030: 'Aim Hero',
#  529830: 'Game Character Hub: Portfolio Edition',
#  539720: 'Razortron 2000',
#  555060: 'Final Soccer VR',
#  559910: 'Terroir',
#  562386: 'Train Simulator: New Haven E-33 Loco Add-On',
#  605450: 'In Death',
#  704010: 'LongStory',
#  769840: 'Muddledash',
#  770972: "Monster Hunter: World - The Handler's Busy Bee Dress",
#  1155660: 'The Deed II',
#  797400: 'Railroad Corporation',
#  824200: 'The Bell Chimes for Gold',
#  832720: 'Dungeon Brewmaster',
#  347213: 'Euro Truck Simulator 2 - Russian Paint Jobs Pack',
#  797280: 'The Surge - Cutting Edge Pack',
#  33780: "Drakensang - Phileasson's Secret",
#  38600: 'Faerie Solitaire',
#  39550: 'SpellForce 2 - Anniversary Edition',
#  204240: 'The Bridge',
#  225820: 'Borderlands 2: Commando Madness Pack',
#  253750: 'Ikaruga',
#  256190: 'Enemy Front',
#  261030: 'The Walking Dead: Season Two',
#  270570: 'Reversion - The Escape (1st Chapter)',
#  283080: 'Super Chibi Knight',
#  304350: 'Wildlife Park 2',
#  308600: 'Gene Shift Auto',
#  313020: 'Soul Gambler',
#  316441: 'DW8XLCE - SPECIAL COSTUME PACK 2',
#  327740: 'TRON 2.0',
#  346180: 'David.',
#  358930: 'Star Control III',
#  1895130: "Darza's Dominion",
#  1926440: 'Twin Edge',
#  1934990: 'Senpai and the Mysterious Dungeon',
#  1947131: 'War Thunder - Type 96A Prototype Pack',
#  1971260: 'Olgob The Bold',
#  1973610: '建安外史 The Tales of Jian An',
#  1991850: 'Navy War: Battleship Games',
#  2013900: '100 hidden turtles',
#  2050050: 'Rift Loopers',
#  2076850: 'Keyboard Warrior: Dreamstate',
#  1895300: 'Shinobi Warfare',
#  1932160: 'Neptunia: Sisters VS Sisters',
#  1149550: 'Utawarerumono: Mask of Deception',
#  1150730: 'Island SAGA',
#  1998750: 'Guilty Gear -Strive- Original Soundtrack Necessary Discrepancy Disc 2',
#  1170970: 'Marbles on Stream',
#  1180900: 'SGS Winter War',
#  1204470: 'Space Elite Force II',
#  1206720: "kraken's curse",
#  1247270: 'Divinity: Original Sin 2 - Official Soundtrack',
#  1254860: 'World Championship Boxing Manager™',
#  1267470: 'Warriors of the Nile',
#  1273260: 'Corpse Party (2021)',
#  1273790: 'Empires and Tribes',
#  1291330: 'Wakamarina Valley New Zealand',
#  1297790: 'Sunday Rivals',
#  1328920: 'Mira and the Mysteries of Alchemy',
#  1345760: 'Matchpoint - Tennis Championships',
#  214590: 'Fairy Bloom Freesia',
#  1367420: 'One Line Coloring',
#  1454050: 'Tour de France 2021',
#  1464060: '\u200bOur Life: Beginnings & Always - Step 1 Expansion',
#  1235762: 'The Sims™ 4 Toddler Stuff',
#  1497820: 'Golden Rails: Small Town Story',
#  1526010: 'Panzer Corps 2: Axis Operations - 1941',
#  1529710: 'Симулятор Прыгания по Гаражам',
#  1530340: 'Incremental Epic Hero',
#  1545250: 'ECHOLOCAUTION',
#  1545600: 'Grapple Hoops',
#  1571140: '东方十昊狱 ～ Hella Dazzling Hell!!',
#  1714440: 'Angels Cove',
#  1174860: 'Tacview',
#  1378990: 'Crash Bandicoot™ 4: It’s About Time',
#  1714460: 'Starry Knight',
#  1739880: 'Blood And Zombies',
#  1825740: 'Fat Baby',
#  1876350: 'HEROish',
#  1941332: 'DCS: F/A-18C Operation Cerberus North',
#  1980490: 'Speedway Challenge 2022',
#  1983420: 'LoFi Hotel',
#  1995870: 'Pixel Survivors : Roguelike',
#  2157060: 'Project Malice',
#  2219200: 'JR EAST Train Simulator: Oito Line (Matsumoto to Minami-Otari) 211 series',
#  2266310: 'REFLEXIA Prototype ver. Original Graphics',
#  11280: "Penguins Arena: Sedna's World",
#  35450: 'Red Orchestra 2: Heroes of Stalingrad with Rising Storm',
#  65300: 'Dustforce DX',
#  73041: 'Majesty 2: Monster Kingdom',
#  205910: "Tiny and Big: Grandpa's Leftovers",
#  248170: 'Clickteam Fusion 2.5',
#  267772: 'Talisman - The Frostmarch Expansion',
#  270760: 'Realms of Arkania 3 - Shadows over Riva Classic',
#  274520: 'Darkwood',
#  279140: 'Making History: The Great War',
#  283940: 'Freddi Fish and the Case of the Missing Kelp Seeds',
#  316060: 'NARUTO SHIPPUDEN: Ultimate Ninja STORM Revolution - DLC9 Variety Pack 3',
#  318520: 'Euro Truck Simulator 2 - Christmas Paint Jobs Pack',
#  328900: 'B-17 Flying Fortress: The Mighty 8th',
#  341090: 'On A Roll 3D',
#  358250: "Cosmo's Cosmic Adventure",
#  363990: 'War for the Overworld - Heart of Gold Expansion',
#  1248432: 'DRAGON BALL FIGHTERZ - Gogeta (SS4)',
#  513730: 'Hyperdimension Neptunia Re;Birth1 Deluxe Pack',
#  364810: 'Star Trek™: Starfleet Academy',
#  365660: 'OlliOlli2: Welcome to Olliwood',
#  365890: 'Heroes of Normandie',
#  400790: 'The Juicer',
#  412770: 'Boogeyman',
#  420640: 'Knights of Pen and Paper 2 - Here Be Dragons',
#  73093: 'Magicka: The Other Side of the Coin',
#  1386611: 'DJMAX RESPECT V - TECHNIKA 2 PACK',
#  457760: 'The Signal From Tölva',
#  461360: 'Thorne - Son of Slaves (Ep.2)',
#  479100: 'Music Wars Empire',
#  486780: 'Fruit Ninja VR',
#  514090: 'Beautiful Japanese Scenery - Animated Jigsaws',
#  522040: 'Princess Remedy 2: In A Heap of Trouble',
#  538710: 'Dead Hungry',
#  541640: 'Disney Infinity 1.0: Gold Edition',
#  573120: 'Dead In Vinland',
#  583640: '100% Orange Juice - Suguri & Hime Winter Costumes',
#  589760: 'Revhead',
#  646662: 'Pinball FX3 - Marvel Pinball Avengers Chronicles',
#  696490: 'TOTOBALL',
#  721340: 'Expansion - Europa Universalis IV: Cradle of Civilization',
#  777670: 'Okinawa Rush',
#  779939: 'DRAGON BALL FIGHTERZ - Cooler',
#  817230: 'Acid Spy',
#  820900: 'Ceress and Orea',
#  839080: 'DRAW CHILLY',
#  210950: 'Rune Classic',
#  840260: 'Endless World Idle RPG',
#  874460: 'Achtung! Cthulhu Tactics',
#  941955: 'Devil May Cry 5 - DMC3 Battle Track 3-Pack',
#  949250: 'Assault Spy - Digital Soundtrack',
#  961990: 'Photo & Graphic Designer 16 Steam Edition',
#  978630: 'Juro Janosik',
#  1039100: 'No Place for Bravery',
#  1052690: 'theHunter: Call of the Wild™ - Trophy Lodge Spring Creek Manor',
#  1099460: 'The Forgotten Land',
#  1166600: 'The Fog Knows Your Name',
#  1168430: 'Dairy Princess',
#  1169100: 'Gazillionaire',
#  1178790: 'Shiren the Wanderer: The Tower of Fortune and the Dice of Fate',
#  1188080: 'Cats are Liquid - A Better Place',
#  1209530: 'F1® 2020: Seventy Edition DLC',
#  1213910: 'Puzzle Battler! Mirai',
#  1270670: 'Touhou Double Focus',
#  1288560: 'My Dear Prince',
#  285820: 'Action Henk',
#  1291010: 'Warpips',
#  1300600: 'Blind Drive',
#  1347751: 'PAYDAY 2: Weapon Color Pack 2',
#  1365750: '东方栖霞园 ~ Blue devil in the\xa0Belvedere.',
#  1453490: 'Deducto',
#  1458690: 'Mango',
#  1461930: 'Robotry!',
#  1503030: 'Street Fighter V - Capcom Pro Tour: 2021 Premier Pass',
#  1503590: 'Range is HOT!',
#  1511090: 'Great Paintings VR',
#  1590712: 'Insurgency: Sandstorm - True Grit Weapon Skin Set',
#  1608040: 'Castle Morihisa',
#  1662010: 'Project Absentia',
#  1728830: 'Space Docker VR',
#  1835840: 'Quarantineer',
#  1888130: 'ALAN-13 Reformation',
#  1906020: 'Drums Rock',
#  1939790: 'Paper Bride 3 Unresolved Love',
#  2001090: 'Lay a Beauty to Rest: A Butterfly Dream',
#  2095140: 'Locked in my darkness',
#  2158240: 'The Trench',
#  2158850: 'Spooky Halloween in the Voxel World',
#  2180310: 'Basement of Hellish',
#  2185770: 'Aonatsu Line',
#  2187660: 'Soccer Clubs',
#  6810: 'Commandos: Beyond the Call of Duty',
#  7020: 'Rogue Trooper',
#  208730: 'Game of Thrones',
#  259510: 'Shufflepuck Cantina Deluxe',
#  271900: 'Hexcells Plus',
#  681240: 'Dujanah',
#  592830: 'Ride 2 Free Bikes Pack 6',
#  314470: 'Heroes of a Broken Land',
#  322660: 'The Binding of Isaac: Rebirth - Soundtrack',
#  338390: 'The Technomancer',
#  343710: 'Kholat',
#  345580: 'Universal Combat CE',
#  348360: 'Doodle God',
#  355050: 'Sky Force Anniversary',
#  355420: 'FLAMBERGE',
#  368430: 'Through the Woods',
#  372800: 'RPG MO',
#  374280: 'Hired Ops',
#  378648: 'The Witcher 3: Wild Hunt - Blood and Wine',
#  381712: 'Resident Evil 0 Costume Pack 3',
#  387984: 'Awesomenauts - 8-Bit Yoolip Skin',
#  391030: 'Hard to Be a God',
#  398915: 'Armello - Seasons Board Skins Pack',
#  570930: 'Redout - Soundtrack',
#  431640: 'Doodle Kingdom',
#  433910: 'Neon Drive',
#  440540: 'Ara Fell: Enhanced Edition',
#  464360: '3030 Deathwar Redux - A Space Odyssey',
#  1199660: 'The Answer Is 42',
#  533950: "Don't open the doors!",
#  544600: "Delicious - Emily's Christmas Carol",
#  565120: 'The Station',
#  572720: 'Nancy Drew®: The Shattered Medallion',
#  584930: 'Conductor',
#  655790: 'Fly Simulator',
#  671600: 'Ashes of Oahu',
#  698890: 'Crypt of the NecroDancer: AMPLIFIED OST - Chipzel',
#  724330: 'Age of Grit',
#  736770: 'Motorsport Manager - Endurance Series',
#  742500: "Nonogram - Master's Legacy",
#  786820: 'SOK MAX',
#  808080: 'Ultimate Racing 2D',
#  998930: 'Seek Girl',
#  1003310: 'Two Point Hospital: Pebberley Island',
#  1045190: "Naval Action - L'Hermione",
#  1065100: 'Golden Treasure: The Great Green',
#  1120810: 'Eastern Exorcist',
#  1148510: 'Pretty Angel',
#  1161410: 'Noita Official Soundtrack',
#  1178230: 'The Wild Case',
#  1192380: 'TOTALLY BASEBALL',
#  1286710: 'Hylics 2',
#  1289211: 'Yakuza: Like a Dragon Legends Costume Set',
#  1290270: 'Vampire: The Masquerade — Night Road',
#  1295510: 'DRAGON QUEST® XI S: Echoes of an Elusive Age™ - Definitive Edition',
#  1298080: 'Almost My Floor',
#  1304420: 'Super Cable Boy',
#  226960: 'Ironclad Tactics',
#  1341210: 'Afterinfection',
#  1395850: 'Home and Dungeon',
#  1406200: 'In My Shadow',
#  1423760: 'War Thunder - French Starter Pack',
#  1446280: 'Alice in Wonderland - a jigsaw puzzle tale',
#  1449510: 'Henchman Story',
#  1452500: 'The Good Life',
#  1469170: 'Commandos 3 - HD Remaster',
#  1493760: 'Youtubers Life 2',
#  273840: 'Stock Car Extreme',
#  1511630: 'TrackDayR',
#  1515320: 'Harvest Days: My Dream Farm',
#  1546930: 'Angry Angry Shark',
#  237010: 'Sanctum 2: Britech Skin Pack',
#  515171: 'Iron Sea - Lost Land',
#  1454970: 'New Tales from the Borderlands',
#  1557860: 'Gear.Club Unlimited 2 - Ultimate Edition',
#  1557990: 'Retail Royale',
#  1576130: 'IdolDays',
#  1589680: 'Torii',
#  1599484: 'Predator: Hunting Grounds - City Hunter Predator DLC Pack',
#  1630110: 'Gungrave G.O.R.E',
#  1632740: 'Fisher Online - USA/Canada: Ontario',
#  1647960: 'Hell Let Loose – Silver Vanguard',
#  1664670: 'Refactor',
#  1666170: 'Vacancy Unlimited',
#  1688120: 'Order of Battle: Allies Resurgent',
#  1707790: 'Dorfs: Hammers for Hire',
#  1744080: 'DRAGON BALL XENOVERSE 2 - Legendary Pack 2',
#  1762770: 'Happy Game Soundtrack + Art Book',
#  1782150: 'OVERLORD: ESCAPE FROM NAZARICK',
#  1092400: '月球坠落时 Moon Fall',
#  1823600: 'Power & Revolution 2022 Edition',
#  1866710: 'Draft Day Sports: College Football 2022',
#  1907080: 'PAYDAY 2: Golden Dagger Tailor Pack',
#  1910320: 'TAPE: Unveil the Memories',
#  1915550: 'Nemesis: Lockdown',
#  1937750: 'Prime of Flames',
#  1986940: 'Forward Defense',
#  2106810: 'The Forest of Drizzling Rain',
#  ...}

# %%
for game in games[:10]:
    print(id_to_title[game])
# Out:
# Casual Penalty
# Dark Parables: Portrait of the Stained Princess Collector's Edition
# MotoGP™20
# Noosphere
# Shisensho Solitaire
# Freud Gate
# Natsu no Iro no Nostalgia
# The Rewinder
# Talesshop Puzzle
# Food Truck Simulator
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(top_k_neighbors)

# %%
print("User Similarity Matrix (Subset):")
print(user_similarity[:5, :5].toarray())
